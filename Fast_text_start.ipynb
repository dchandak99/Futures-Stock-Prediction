# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 5000)

# %%
df=pd.read_csv('final_merged.csv').drop('Unnamed: 0',axis=1)
df.head(5000)
# Out:
#                                     Bucket  \
# 0                 00::00::Commodities::USA
# 1                          00::00::FX::USA
# 2              00::00::Fixed Income::Korea
# 3                 00::01::Commodities::USA
# 4                          00::01::FX::USA
# 5              00::01::Fixed Income::Korea
# 6                 00::02::Commodities::USA
# 7                          00::02::FX::USA
# 8              00::02::Fixed Income::Korea
# 9                 00::03::Commodities::USA
# 10                         00::03::FX::USA
# 11             00::03::Fixed Income::Korea
# 12                00::04::Commodities::USA
# 13                         00::04::FX::USA
# 14             00::04::Fixed Income::Korea
# 15                00::05::Commodities::USA
# 16                         00::05::FX::USA
# 17             00::05::Fixed Income::Korea
# 18                00::06::Commodities::USA
# 19                         00::06::FX::USA
# 20             00::06::Fixed Income::Korea
# ...

# %%
len(df)
# Out:
# 7673
